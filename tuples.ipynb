# %%
#tuples are immutable,ordered, allowduplication, indexed
t=(10,)
print(type(t))
# Out:
# <class 'tuple'>

# %%
t=()
type(t)
# Out:
# tuple

# %%
t=10,20,30
print(t)
type(t)
# Out:
# (10, 20, 30)
# tuple

# %%
t=(10)#comma not there so tuple
type(t)
# Out:
# int

# %%
#accessing tuple elements
t=10,20,30,40
s=t[1]
print(s)
c
t=10,20,30,40
s=t[1:4]
print(s)
# Out:
# 20
# (20, 30, 40)

# %%
#item assignment not possible for tuple due to immutability
t=(10,20,30,40)
t[1]=20
print(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 #item assignment not possible for tuple due to immutability
#       2 t=(10,20,30,40)
# ----> 3 t[1]=20
#       4 print(t)
#
# TypeError: 'tuple' object does not support item assignment

# %%
t = (10, 20, 30, 40, 50)
print(t.index(30))#based on position
# Out:
# 2

# %%
#indexing-accessing elements based on index
t = (10, 20, 30, 40, 50)
print(t[0])   # first element
print(t[2])   # third element
print(t[-1])  # last element
# Out:
# 10
# 30
# 50

# %%
t1 = (1, 2, 3)
t2 = (4, 5, 6)
#conncatenation
t3 = t1 + t2
print(t3)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
t = (5, 10)
#replication
print(t * 3)
# Out:
# (5, 10, 5, 10, 5, 10)

# %%
t = (1, 2, 3, 2, 4, 2)
#counting
print(t.count(2))
# Out:
# 3

# %%
t = (10, 20, 30, 40, 50)
#slicing-get range of values
print(t[1:4])
print(t[:3])
print(t[2:])
# Out:
# (20, 30, 40)
# (10, 20, 30)
# (30, 40, 50)

# %%
#nesting tuple
t=(10,2.5,(20,30,60),"s")
print(t[2][2])
type(t)
# Out:
# 60
# tuple

# %%
#covert list to tuple
l1=[54,32,17,6]
t=tuple(l1)
print(t)
# Out:
# (54, 32, 17, 6)
