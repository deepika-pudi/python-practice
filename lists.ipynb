# %%
#lists-ordered,mutable,indexded
l1=[1,2.3,"s",1,1]
print(len(l1))
# Out:
# 5

# %%
l2=[1,2.3,"s",1,1]
l2.append(50)
print(l2)
l2.remove(1)
print(l2)
# Out:
# [1, 2.3, 's', 1, 1, 50]
# [2.3, 's', 1, 1, 50]

# %%
d=[10,20,50,16]
d.pop(1)#giving index pop index, if empty it will pop at end
print(d)
d.insert(2,290)
print(d)
d.sort()
print(d)
d.reverse()
print(d)
# Out:
# [10, 50, 16]
# [10, 50, 290, 16]
# [10, 16, 50, 290]
# [290, 50, 16, 10]

# %%
#index
dp=[10,20.40]
print(dp.index(10))#position
# Out:
# 0

# %%
l=[30,20,7,50,12]
l.remove(30)
print(l)
l.insert(3,12)
print(l)
l.sort()
print(l)
# Out:
# [20, 7, 50, 12]
# [20, 7, 50, 12, 12]
# [7, 12, 12, 20, 50]

# %%
num=[3,9,0,54,32]
for i in num:
    print(i)
# Out:
# 3
# 9
# 0
# 54
# 32

# %%
numbers = [10, 20, 30, 40, 50, 60, 70]

for num in numbers:
    print(num)
# Out:
# 10
# 20
# 30
# 40
# 50
# 60
# 70

# %%
#list slicing
employee=['ramu', 12 ,1800,21]
print(employee[1:3])
# Out:
# [12, 1800]

# %%
list1 = [10, 20, 30, 40]

list1[1] = 25

print(list1)
# Out:
# [10, 25, 30, 40]

# %%
#sorted
nums = [5, 2, 9, 1]
print(sorted(nums))
print(nums)# it returns new list
# Out:
# [1, 2, 5, 9]
# [5, 2, 9, 1]

# %%
nums = [1, 2, 3, 4, 5]
print(list(reversed(nums)))
# Out:
# [5, 4, 3, 2, 1]
