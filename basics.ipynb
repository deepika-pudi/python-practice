# %%
m,d = input("enter two values:").split()
print(m)
print(d)
type(m)
# Out:
# enter two values: 1 2
# 1
# 2
# str

# %%
a,b,c = map(int,input("enter three values:").split())
print(a)
print(b)
print(c) 
type(a)
# Out:
# enter three values: 2 1 2
# 2
# 1
# 2
# int

# %%
#arthimetic operators #
A=int(input("enter a value"))
B=int(input("enter b value"))
C=A+B
print(C)
# Out:
# enter a value 3
# enter b value 2
# 5

# %%
''' writing a python program values
using arithemetic operators'''
a=2
b=3
c=a+b
print(c)
type(a)
# Out:
# 5
# int

# %%
#comparision operators #
a=5
b=3
if(a==b):
    print("a and b values are same")
else:
    print("a and b values are not same")
# Out:
# a and b values are not same

# %%
a=2
b=3
if(a<b):
    print(a)
else:
    print(b)
# Out:
# 2

# %%
'''writing a python prm
 without using if condition for comparision operators'''
a=2
b=7
print(a<b,"a is smaller than b")
# Out:
# True a is smaller than b

# %%
a=5
b=3
if(a==b):
    print("a and b values are same")
else:
    print("a and b values are not same")
# Out:
# a and b values are not same

# %%
#logical operators for AND#
a=2
b=5
if a>0 and b>3:
    print("false")
# Out:
# false

# %%
#for or #
a=2
if a>0 :
    print("true")
# Out:
# true

# %%
#basic code inputs for practicing
name=input("enter your name")
age=int(input("enter your age"))
price=float(input("enter your price"))
x,y=input("enter x, y").split()
x,y=map(int,input("enter x,y").split())
x,y=list(map("enter x,y").split())

# %%
#practicing
#comparision operators
a=5
b=4
if (a==b):
    print("a and b values are same")
else:
    print("a and b values are not same")
# Out:
# a and b values are not same

# %%
a=5
b=2
print(a!=b,"a and b values are  not same")
# Out:
# True a and b values are  not same

# %%
#logical operator not
a=5
b=2
if not (a == b):
    print("a and b are not equal.")
else:
    print("a and b are equal.")
# Out:
# a and b are not equal.

# %%
#logical or operator
a = 5
b = 2

if a > 3 or b > 10:
    print("At least one condition is True")
else:
    print("Both conditions are False")
# Out:
# At least one condition is True

# %%
#bitwise operators
#AND
a=3 # 11
b=4 #100
a&b #000-0(result)
# Out:
# 0

# %%
#OR
a=4 #0100
b=5 #0101
a|b #0101-5(result)
# Out:
# 5

# %%
#XOR
a=2 # 10
b=4 #100
a^b #110-6(result)
# Out:
# 6

# %%
#NOT
b=4 
#formulae -(b+1)=>-(4+1)=-5
~b
# Out:
# -5

# %%
#left shift-multiply by 2
a=6  #6*((2)^2)
a<<2
# Out:
# 24

# %%
#right shift-divide by 2
a=6 #6/((2)^2)
a>>2
# Out:
# 1

# %%
#identity operator
x=10
d=10
b=9
x is not b
# Out:
# True

# %%
#membership operator
x=[1,2,4,5,9]
4 not in x
# Out:
# False

# %%
#ternary operator in python
#syn- val_if_true if condition else val_if_false
a=10
b=20
max=a if a>b else b
print(max)
# Out:
# 20

# %%
#check even or odd
n=9
result="even"if n%3!=0 else "odd"
print(result)
# Out:
# odd

# %%
# Out:
# 0
